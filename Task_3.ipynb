# %% [markdown]
# <a href="https://colab.research.google.com/github/dharinidakshin05/PRODIGY_DS_TASK-3/blob/main/Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the accident data
accident_data = pd.read_csv('/content/accident data.csv')
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of accidents by hour and day of the week
x = [.2,.4,.6,.8]
y = [.2,.4,.6,.8]
plt.plot(x,y,color ='blue')
plt.figure(figsize=(10, 8))
plt.xlabel('Day of the Week')
plt.ylabel('Hour of the Day')
plt.title('Accidents by Hour and Day of the Week')
plt.show()

# %%
# !https://github.com/dharinidakshin05/PRODIGY_DS_TASK-3.git
# Out:
# /bin/bash: line 1: https://github.com/dharinidakshin05/PRODIGY_DS_TASK-3.git: No such file or directory
